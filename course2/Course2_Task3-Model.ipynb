# %% [markdown]
# # Import and Prepare the Data

# %%
# When we work with files in Python we will be using the Pandas library. 
# In order to access different functions and methods inside of the library we must first import it into our project. 
#
import pandas as pd

# %%
# We can use the new 'pd' reference and run the read_csv function from within Pandas to import our data as follows:
# We will name the dataframe 'credit'.
credit = pd.read_csv('default of credit card clients.csv', header =1)
#
# Note that the first row of the data file is excluded.

# %%
# Use the get_dummies() function within pandas to convert non-numeric columns to a series of binary numeric 'Dummy' columns
credit1 = pd.get_dummies(credit)
# Print credit
credit1
# Out:
#           ID  LIMIT_BAL  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  PAY_5  \
# 0          1      20000         1   24      2      2     -1     -1     -2
# 1          2     120000         2   26     -1      2      0      0      0
# 2          3      90000         2   34      0      0      0      0      0
# 3          4      50000         1   37      0      0      0      0      0
# 4          5      50000         1   57     -1      0     -1      0      0
# ...      ...        ...       ...  ...    ...    ...    ...    ...    ...
# 29995  29996     220000         1   39      0      0      0      0      0
# 29996  29997     150000         2   43     -1     -1     -1     -1      0
# 29997  29998      30000         2   37      4      3      2     -1      0
# 29998  29999      80000         1   41      1     -1      0      0      0
# 29999  30000      50000         1   46      0      0      0      0      0
#
#        PAY_6  ...  PAY_AMT5  PAY_AMT6  SEX_female  SEX_male  \
# 0         -2  ...         0         0           1         0
# 1          2  ...         0      2000           1         0
# 2          0  ...      1000      5000           1         0
# 3          0  ...      1069      1000           1         0
# 4          0  ...       689       679           0         1
# ...      ...  ...       ...       ...         ...       ...
# 29995      0  ...      5000      1000           0         1
# 29996      0  ...         0         0           0         1
# 29997      0  ...      2000      3100           0         1
# 29998     -1  ...     52964      1804           0         1
# 29999      0  ...      1000      1000           0         1
#
#        EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# 0                              0                      0                0
# 1                              0                      0                0
# 2                              0                      0                0
# 3                              0                      0                0
# 4                              0                      0                0
# ...                          ...                    ...              ...
# 29995                          0                      1                0
# 29996                          0                      1                0
# 29997                          0                      0                0
# 29998                          0                      1                0
# 29999                          0                      0                0
#
#        EDUCATION_university  default payment next month_default  \
# 0                         1                                   1
# 1                         1                                   1
# 2                         1                                   0
# 3                         1                                   0
# 4                         1                                   0
# ...                     ...                                 ...
# 29995                     0                                   0
# 29996                     0                                   0
# 29997                     1                                   1
# 29998                     0                                   1
# 29999                     1                                   1
#
#        default payment next month_not default
# 0                                           0
# 1                                           0
# 2                                           1
# 3                                           1
# 4                                           1
# ...                                       ...
# 29995                                       1
# 29996                                       1
# 29997                                       0
# 29998                                       0
# 29999                                       0
#
# [30000 rows x 30 columns]

# %% [markdown]
# The categorical variables SEX and EDUCATION are now converted to dummy variables.

# %% [markdown]
# # Pandas-Profiling

# %% [markdown]
# We can also use Pandas-Profiling to quickly create an EDA-like report in just one line of code!
# To do this, we'll need to import the pandas-profiling library into work environment.
# Go to https://anaconda.org/conda-forge/pandas-profiling for installation instruction

# %%
# import pandas-profiling library
import pandas_profiling

# %%
# Now we can use the library on our data frame
pandas_profiling.ProfileReport(credit1)

# %% [markdown]
# This is really a great tool to provide basic statistical analyses on all the variables: key summaries and visualization, including graphically shown at least 4 different correlations, pin point the highest pairwise correlated factors, etc.

# %%
import pandas as pd
import matplotlib.pyplot as plt # visualize data graphically

# %% [markdown]
# # Correlation

# %% [markdown]
# Whether addressing collinearity or checking for relationships between features for selection or engineering, calculating correlation is a vital part of all Data Science projects:

# %%
# building a basic correlation coefficient matrix using pandas:
# Strength of correlations:
#   Very strong relationship  (|r| >= 0.8)
#   Strong relationship       (|r| >= 0.6)
#   Moderate relationship     (|r| >= 0.4)
#   Weak relationship         (|r| >= 0.2)
#   Very weak relationship    (0< |r|< 0.2)

corrMat = credit1.corr()
print(corrMat)
# Out:
#                                               ID  LIMIT_BAL  MARRIAGE  \
# ID                                      1.000000   0.026179 -0.029079
# LIMIT_BAL                               0.026179   1.000000 -0.108139
# MARRIAGE                               -0.029079  -0.108139  1.000000
# AGE                                     0.018678   0.144713 -0.414170
# PAY_0                                  -0.030575  -0.271214  0.019917
# PAY_2                                  -0.011215  -0.296382  0.024199
# PAY_3                                  -0.018494  -0.286123  0.032688
# PAY_4                                  -0.002735  -0.267460  0.033122
# PAY_5                                  -0.022199  -0.249411  0.035629
# PAY_6                                  -0.020270  -0.235195  0.034345
# BILL_AMT1                               0.019389   0.285430 -0.023472
# BILL_AMT2                               0.017982   0.278314 -0.021602
# BILL_AMT3                               0.024354   0.283236 -0.024909
# BILL_AMT4                               0.040351   0.293988 -0.023344
# BILL_AMT5                               0.016705   0.295562 -0.025393
# BILL_AMT6                               0.016730   0.290389 -0.021207
# PAY_AMT1                                0.009742   0.195236 -0.005979
# PAY_AMT2                                0.008406   0.178408 -0.008093
# PAY_AMT3                                0.039151   0.210167 -0.003541
# PAY_AMT4                                0.007793   0.203242 -0.012659
# PAY_AMT5                                0.000652   0.217202 -0.001205
# PAY_AMT6                                0.003000   0.219595 -0.006641
# SEX_female                              0.018497   0.024755 -0.031389
# SEX_male                               -0.018497  -0.024755  0.031389
# EDUCATION_graduate school              -0.025858   0.258777  0.142129
# EDUCATION_high school                   0.017475  -0.139686 -0.110845
# EDUCATION_other                         0.037165   0.013420 -0.008386
# EDUCATION_university                    0.002569  -0.147530 -0.051797
# default payment next month_default     -0.013952  -0.153520 -0.024339
# default payment next month_not default  0.013952   0.153520  0.024339
#
#                                              AGE     PAY_0     PAY_2  \
# ID                                      0.018678 -0.030575 -0.011215
# LIMIT_BAL                               0.144713 -0.271214 -0.296382
# MARRIAGE                               -0.414170  0.019917  0.024199
# AGE                                     1.000000 -0.039447 -0.050148
# PAY_0                                  -0.039447  1.000000  0.672164
# PAY_2                                  -0.050148  0.672164  1.000000
# PAY_3                                  -0.053048  0.574245  0.766552
# PAY_4                                  -0.049722  0.538841  0.662067
# PAY_5                                  -0.053826  0.509426  0.622780
# PAY_6                                  -0.048773  0.474553  0.575501
# BILL_AMT1                               0.056239  0.187068  0.234887
# BILL_AMT2                               0.054283  0.189859  0.235257
# BILL_AMT3                               0.053710  0.179785  0.224146
# BILL_AMT4                               0.051353  0.179125  0.222237
# BILL_AMT5                               0.049345  0.180635  0.221348
# BILL_AMT6                               0.047613  0.176980  0.219403
# PAY_AMT1                                0.026147 -0.079269 -0.080701
# PAY_AMT2                                0.021785 -0.070101 -0.058990
# PAY_AMT3                                0.029247 -0.070561 -0.055901
# PAY_AMT4                                0.021379 -0.064005 -0.046858
# PAY_AMT5                                0.022850 -0.058190 -0.037093
# PAY_AMT6                                0.019478 -0.058673 -0.036500
# SEX_female                             -0.090874 -0.057643 -0.070771
# SEX_male                                0.090874  0.057643  0.070771
# EDUCATION_graduate school              -0.100423 -0.142720 -0.169215
# EDUCATION_high school                   0.231252  0.058902  0.064590
# EDUCATION_other                         0.008982 -0.024937 -0.033118
# EDUCATION_university                   -0.077626  0.099177  0.122364
# default payment next month_default      0.013890  0.324794  0.263551
# default payment next month_not default -0.013890 -0.324794 -0.263551
#
#                                            PAY_3     PAY_4     PAY_5  \
# ID                                     -0.018494 -0.002735 -0.022199
# LIMIT_BAL                              -0.286123 -0.267460 -0.249411
# MARRIAGE                                0.032688  0.033122  0.035629
# AGE                                    -0.053048 -0.049722 -0.053826
# PAY_0                                   0.574245  0.538841  0.509426
# PAY_2                                   0.766552  0.662067  0.622780
# PAY_3                                   1.000000  0.777359  0.686775
# PAY_4                                   0.777359  1.000000  0.819835
# PAY_5                                   0.686775  0.819835  1.000000
# PAY_6                                   0.632684  0.716449  0.816900
# BILL_AMT1                               0.208473  0.202812  0.206684
# BILL_AMT2                               0.237295  0.225816  0.226913
# BILL_AMT3                               0.227494  0.244983  0.243335
# BILL_AMT4                               0.227202  0.245917  0.271915
# BILL_AMT5                               0.225145  0.242902  0.269783
# BILL_AMT6                               0.222327  0.239154  0.262509
# PAY_AMT1                                0.001295 -0.009362 -0.006089
# PAY_AMT2                               -0.066793 -0.001944 -0.003191
# PAY_AMT3                               -0.053311 -0.069235  0.009062
# PAY_AMT4                               -0.046067 -0.043461 -0.058299
# PAY_AMT5                               -0.035863 -0.033590 -0.033337
# PAY_AMT6                               -0.035861 -0.026565 -0.023027
# SEX_female                             -0.066096 -0.060173 -0.055064
# SEX_male                                0.066096  0.060173  0.055064
# EDUCATION_graduate school              -0.160209 -0.152402 -0.138709
# EDUCATION_high school                   0.062461  0.058382  0.049577
# EDUCATION_other                        -0.034435 -0.030998 -0.028822
# EDUCATION_university                    0.115644  0.110340  0.103218
# default payment next month_default      0.235253  0.216614  0.204149
# default payment next month_not default -0.235253 -0.216614 -0.204149
#
#                                            PAY_6  ...  PAY_AMT5  PAY_AMT6  \
# ID                                     -0.020270  ...  0.000652  0.003000
# LIMIT_BAL                              -0.235195  ...  0.217202  0.219595
# MARRIAGE                                0.034345  ... -0.001205 -0.006641
# AGE                                    -0.048773  ...  0.022850  0.019478
# PAY_0                                   0.474553  ... -0.058190 -0.058673
# PAY_2                                   0.575501  ... -0.037093 -0.036500
# PAY_3                                   0.632684  ... -0.035863 -0.035861
# PAY_4                                   0.716449  ... -0.033590 -0.026565
# PAY_5                                   0.816900  ... -0.033337 -0.023027
# PAY_6                                   1.000000  ... -0.046434 -0.025299
# BILL_AMT1                               0.207373  ...  0.167026  0.179341
# BILL_AMT2                               0.226924  ...  0.157957  0.174256
# BILL_AMT3                               0.241181  ...  0.179712  0.182326
# BILL_AMT4                               0.266356  ...  0.160433  0.177637
# BILL_AMT5                               0.290894  ...  0.141574  0.164184
# BILL_AMT6                               0.285091  ...  0.307729  0.115494
# PAY_AMT1                               -0.001496  ...  0.148459  0.185735
# PAY_AMT2                               -0.005223  ...  0.180908  0.157634
# PAY_AMT3                                0.005834  ...  0.159214  0.162740
# PAY_AMT4                                0.019018  ...  0.151830  0.157834
# PAY_AMT5                               -0.046434  ...  1.000000  0.154896
# PAY_AMT6                               -0.025299  ...  0.154896  1.000000
# SEX_female                             -0.044008  ... -0.001667 -0.002766
# SEX_male                                0.044008  ...  0.001667  0.002766
# EDUCATION_graduate school              -0.125123  ...  0.047226  0.050135
# EDUCATION_high school                   0.041370  ... -0.034768 -0.034613
# EDUCATION_other                        -0.035733  ...  0.007395  0.016008
# EDUCATION_university                    0.098013  ... -0.021270 -0.026310
# default payment next month_default      0.186866  ... -0.055124 -0.053183
# default payment next month_not default -0.186866  ...  0.055124  0.053183
#
#                                         SEX_female  SEX_male  \
# ID                                        0.018497 -0.018497
# LIMIT_BAL                                 0.024755 -0.024755
# MARRIAGE                                 -0.031389  0.031389
# AGE                                      -0.090874  0.090874
# PAY_0                                    -0.057643  0.057643
# PAY_2                                    -0.070771  0.070771
# PAY_3                                    -0.066096  0.066096
# PAY_4                                    -0.060173  0.060173
# PAY_5                                    -0.055064  0.055064
# PAY_6                                    -0.044008  0.044008
# BILL_AMT1                                -0.033642  0.033642
# BILL_AMT2                                -0.031183  0.031183
# BILL_AMT3                                -0.024563  0.024563
# BILL_AMT4                                -0.021880  0.021880
# BILL_AMT5                                -0.017005  0.017005
# BILL_AMT6                                -0.016733  0.016733
# PAY_AMT1                                 -0.000242  0.000242
# PAY_AMT2                                 -0.001391  0.001391
# PAY_AMT3                                 -0.008597  0.008597
# PAY_AMT4                                 -0.002229  0.002229
# PAY_AMT5                                 -0.001667  0.001667
# PAY_AMT6                                 -0.002766  0.002766
# SEX_female                                1.000000 -1.000000
# SEX_male                                 -1.000000  1.000000
# EDUCATION_graduate school                -0.022750  0.022750
# EDUCATION_high school                    -0.007650  0.007650
# EDUCATION_other                           0.008498 -0.008498
# EDUCATION_university                      0.025353 -0.025353
# default payment next month_default       -0.039961  0.039961
# default payment next month_not default    0.039961 -0.039961
#
#                                         EDUCATION_graduate school  \
# ID                                                      -0.025858
# LIMIT_BAL                                                0.258777
# MARRIAGE                                                 0.142129
# AGE                                                     -0.100423
# PAY_0                                                   -0.142720
# PAY_2                                                   -0.169215
# PAY_3                                                   -0.160209
# PAY_4                                                   -0.152402
# PAY_5                                                   -0.138709
# PAY_6                                                   -0.125123
# BILL_AMT1                                               -0.024045
# BILL_AMT2                                               -0.020334
# BILL_AMT3                                               -0.013112
# BILL_AMT4                                               -0.003809
# BILL_AMT5                                                0.000941
# BILL_AMT6                                               -0.002525
# PAY_AMT1                                                 0.049811
# PAY_AMT2                                                 0.044400
# PAY_AMT3                                                 0.055982
# PAY_AMT4                                                 0.046119
# PAY_AMT5                                                 0.047226
# PAY_AMT6                                                 0.050135
# SEX_female                                              -0.022750
# SEX_male                                                 0.022750
# EDUCATION_graduate school                                1.000000
# EDUCATION_high school                                   -0.326917
# EDUCATION_other                                         -0.092951
# EDUCATION_university                                    -0.692075
# default payment next month_default                      -0.051328
# default payment next month_not default                   0.051328
#
#                                         EDUCATION_high school  \
# ID                                                   0.017475
# LIMIT_BAL                                           -0.139686
# MARRIAGE                                            -0.110845
# AGE                                                  0.231252
# PAY_0                                                0.058902
# PAY_2                                                0.064590
# PAY_3                                                0.062461
# PAY_4                                                0.058382
# PAY_5                                                0.049577
# PAY_6                                                0.041370
# BILL_AMT1                                           -0.022006
# BILL_AMT2                                           -0.022761
# BILL_AMT3                                           -0.022807
# BILL_AMT4                                           -0.031276
# BILL_AMT5                                           -0.031708
# BILL_AMT6                                           -0.030981
# PAY_AMT1                                            -0.021310
# PAY_AMT2                                            -0.016674
# PAY_AMT3                                            -0.031726
# PAY_AMT4                                            -0.023554
# PAY_AMT5                                            -0.034768
# PAY_AMT6                                            -0.034613
# SEX_female                                          -0.007650
# SEX_male                                             0.007650
# EDUCATION_graduate school                           -0.326917
# EDUCATION_high school                                1.000000
# EDUCATION_other                                     -0.055736
# EDUCATION_university                                -0.414989
# default payment next month_default                   0.032403
# default payment next month_not default              -0.032403
#
#                                         EDUCATION_other  EDUCATION_university  \
# ID                                             0.037165              0.002569
# LIMIT_BAL                                      0.013420             -0.147530
# MARRIAGE                                      -0.008386             -0.051797
# AGE                                            0.008982             -0.077626
# PAY_0                                         -0.024937              0.099177
# PAY_2                                         -0.033118              0.122364
# PAY_3                                         -0.034435              0.115644
# PAY_4                                         -0.030998              0.110340
# PAY_5                                         -0.028822              0.103218
# PAY_6                                         -0.035733              0.098013
# BILL_AMT1                                      0.036364              0.030323
# BILL_AMT2                                      0.030778              0.028716
# BILL_AMT3                                      0.028952              0.022288
# BILL_AMT4                                      0.020954              0.021648
# BILL_AMT5                                      0.011811              0.019690
# BILL_AMT6                                      0.003417              0.024555
# PAY_AMT1                                       0.004445             -0.032998
# PAY_AMT2                                       0.012004             -0.033132
# PAY_AMT3                                       0.022272             -0.035608
# PAY_AMT4                                       0.001095             -0.026965
# PAY_AMT5                                       0.007395             -0.021270
# PAY_AMT6                                       0.016008             -0.026310
# SEX_female                                     0.008498              0.025353
# SEX_male                                      -0.008498             -0.025353
# EDUCATION_graduate school                     -0.092951             -0.692075
# EDUCATION_high school                         -0.055736             -0.414989
# EDUCATION_other                                1.000000             -0.117992
# EDUCATION_university                          -0.117992              1.000000
# default payment next month_default            -0.045703              0.036467
# default payment next month_not default         0.045703             -0.036467
#
#                                         default payment next month_default  \
# ID                                                               -0.013952
# LIMIT_BAL                                                        -0.153520
# MARRIAGE                                                         -0.024339
# AGE                                                               0.013890
# PAY_0                                                             0.324794
# PAY_2                                                             0.263551
# PAY_3                                                             0.235253
# PAY_4                                                             0.216614
# PAY_5                                                             0.204149
# PAY_6                                                             0.186866
# BILL_AMT1                                                        -0.019644
# BILL_AMT2                                                        -0.014193
# BILL_AMT3                                                        -0.014076
# BILL_AMT4                                                        -0.010156
# BILL_AMT5                                                        -0.006760
# BILL_AMT6                                                        -0.005372
# PAY_AMT1                                                         -0.072929
# PAY_AMT2                                                         -0.058579
# PAY_AMT3                                                         -0.056250
# PAY_AMT4                                                         -0.056827
# PAY_AMT5                                                         -0.055124
# PAY_AMT6                                                         -0.053183
# SEX_female                                                       -0.039961
# SEX_male                                                          0.039961
# EDUCATION_graduate school                                        -0.051328
# EDUCATION_high school                                             0.032403
# EDUCATION_other                                                  -0.045703
# EDUCATION_university                                              0.036467
# default payment next month_default                                1.000000
# default payment next month_not default                           -1.000000
#
#                                         default payment next month_not default
# ID                                                                    0.013952
# LIMIT_BAL                                                             0.153520
# MARRIAGE                                                              0.024339
# AGE                                                                  -0.013890
# PAY_0                                                                -0.324794
# PAY_2                                                                -0.263551
# PAY_3                                                                -0.235253
# PAY_4                                                                -0.216614
# PAY_5                                                                -0.204149
# PAY_6                                                                -0.186866
# BILL_AMT1                                                             0.019644
# BILL_AMT2                                                             0.014193
# BILL_AMT3                                                             0.014076
# BILL_AMT4                                                             0.010156
# BILL_AMT5                                                             0.006760
# BILL_AMT6                                                             0.005372
# PAY_AMT1                                                              0.072929
# PAY_AMT2                                                              0.058579
# PAY_AMT3                                                              0.056250
# PAY_AMT4                                                              0.056827
# PAY_AMT5                                                              0.055124
# PAY_AMT6                                                              0.053183
# SEX_female                                                            0.039961
# SEX_male                                                             -0.039961
# EDUCATION_graduate school                                             0.051328
# EDUCATION_high school                                                -0.032403
# EDUCATION_other                                                       0.045703
# EDUCATION_university                                                 -0.036467
# default payment next month_default                                   -1.000000
# default payment next month_not default                                1.000000
#
# [30 rows x 30 columns]

# %%
# Create Pearson correlation matrix visualization, and limit to 2 decimal places:
corrMat.style.background_gradient(cmap='coolwarm').set_precision(2)

# %% [markdown]
# # CREATE NEW VARIABLES

# %%
# create Age_GP by tweenties, thirties, etc
# Use floor_divide by 10 to get the tens, then multiply by 10. 
import numpy as np
credit1['AGE_GP'] = np.floor_divide(credit1['AGE'],10) * 10
credit1['AGE_GP']

# %%
# Now we can use the library on our data frame
pandas_profiling.ProfileReport(credit)

# %% [markdown]
# PAY_x with x = 0, 2, 3, 4, 5 ,6 indicate about 50% are using the revolving payment.

# %%
# Create a variable TOTAL_BILL as the sum of all the 6 months' BILL_AMTs
credit1["TOTAL_BILL"] = credit1["BILL_AMT1"]+credit1["BILL_AMT2"]+credit1["BILL_AMT3"]+credit1["BILL_AMT4"]+credit1["BILL_AMT5"]+credit1["BILL_AMT6"]

# %%
# Create a variable TOTAL_PAY as the sum of all the 6 months' PAY_AMTs
credit1["TOTAL_PAY"] = credit1["PAY_AMT1"]+credit1["PAY_AMT2"]+credit1["PAY_AMT3"]+credit1["PAY_AMT4"]+credit1["PAY_AMT5"]+credit1["PAY_AMT6"]

# %%
# Add 2 to each PAY_x, so all will be non-negative. 
# Create a variable PAY_STAT1
credit1["PAY_STATUS"] = credit1["PAY_0"]+credit1["PAY_2"]+credit1["PAY_3"]+credit1["PAY_4"]+credit1["PAY_5"]+credit1["PAY_6"]+12

# %% [markdown]
# # Factors affecting Default

# %%
#reload file with some data manipulation
df = pd.read_csv('default of credit card clients_analysis.csv', header=1)
df.head()
# Out:
#    ID  LIMIT_BAL     SEX   EDUCATION  MARRIAGE  AGE  PAY_Status  TOT_BILL  \
# 0   1      20000  female  university         1   24          13      7704
# 1   2     120000  female  university         2   26          15     17077
# 2   3      90000  female  university         2   34          12    103171
# 3   4      50000  female  university         1   37          10    233334
# 4   5      50000    male  university         1   57          10    111339
#
#    TOT_PAY  PAY_0  ...  exPAY_2  exPAY_3  exPAY_4  exPAY_5  exPAY_6  \
# 0      689      2  ...        0        0       -2       -2       -2
# 1     5000     -1  ...        0        0        1        0        2
# 2    11018      0  ...        0        0        0        0        0
# 3     8388      0  ...        0        0        0        0        0
# 4    59049     -1  ...       -1        0        0        0        0
#
#    exPAY_positive  exPAY0  eXPAY-1  exPAY-2  TOT_SPEND
# 0               0       3        0        3       4602
# 1               2       4        0        0       5682
# 2               0       6        0        0      35257
# 3               0       6        0        0      54378
# 4               0       5        1        0      66987
#
# [5 rows x 47 columns]

# %%
# Use the get_dummies() function within pandas to convert non-numeric columns to a series of binary numeric 'Dummy' columns
df = pd.get_dummies(df)
df.head()
# Out:
#    ID  LIMIT_BAL  MARRIAGE  AGE  PAY_Status  TOT_BILL  TOT_PAY  PAY_0  PAY_2  \
# 0   1      20000         1   24          13      7704      689      2      2
# 1   2     120000         2   26          15     17077     5000     -1      2
# 2   3      90000         2   34          12    103171    11018      0      0
# 3   4      50000         1   37          10    233334     8388      0      0
# 4   5      50000         1   57          10    111339    59049     -1      0
#
#    PAY_3  ...  exPAY-2  TOT_SPEND  SEX_female  SEX_male  \
# 0     -1  ...        3       4602           1         0
# 1      0  ...        0       5682           1         0
# 2      0  ...        0      35257           1         0
# 3      0  ...        0      54378           1         0
# 4     -1  ...        0      66987           0         1
#
#    EDUCATION_graduate school  EDUCATION_high school  EDUCATION_other  \
# 0                          0                      0                0
# 1                          0                      0                0
# 2                          0                      0                0
# 3                          0                      0                0
# 4                          0                      0                0
#
#    EDUCATION_university  default payment next month_default  \
# 0                     1                                   1
# 1                     1                                   1
# 2                     1                                   0
# 3                     1                                   0
# 4                     1                                   0
#
#    default payment next month_not default
# 0                                       0
# 1                                       0
# 2                                       1
# 3                                       1
# 4                                       1
#
# [5 rows x 52 columns]

# %%
df1=df.drop(['SEX_male','EDUCATION_other','PAY_0','PAY_2','PAY_3','PAY_4','PAY_5','PAY_6','BILL_AMT1','BILL_AMT2','BILL_AMT3','BILL_AMT4','BILL_AMT5','BILL_AMT6','Spend_1','Spend_2','Spend_3','Spend_4','Spend_5','Spend_6','PAY_AMT1','PAY_AMT2','PAY_AMT3','PAY_AMT4','PAY_AMT5','PAY_AMT6','exPAY_1','exPAY_2','exPAY_3','exPAY_4','exPAY_5','exPAY_6','exPAY0','eXPAY-1','exPAY-2'], axis=1)

# %%
#look at the correlation of the new data
df1_corrMat = df1.corr()
df1_corrMat.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style  type="text/css" >
#     #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col1 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col2 {
#             background-color:  #94b6ff;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col3 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col4 {
#             background-color:  #7295f4;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col5 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col6 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col7 {
#             background-color:  #82a6fb;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col8 {
#             background-color:  #7396f5;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col9 {
#             background-color:  #7597f6;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col10 {
#             background-color:  #92b4fe;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col11 {
#             background-color:  #5977e3;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col12 {
#             background-color:  #bed2f6;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col13 {
#             background-color:  #a1c0ff;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col14 {
#             background-color:  #c4d5f3;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col15 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row0_col16 {
#             background-color:  #dedcdb;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col0 {
#             background-color:  #4b64d5;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col2 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col3 {
#             background-color:  #bfd3f6;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col5 {
#             background-color:  #d7dce3;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col6 {
#             background-color:  #d5dbe5;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col7 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col8 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col9 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col10 {
#             background-color:  #e5d8d1;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col11 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col12 {
#             background-color:  #ebd3c6;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col13 {
#             background-color:  #799cf8;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col14 {
#             background-color:  #a6c4fe;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col15 {
#             background-color:  #c7d7f0;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row1_col16 {
#             background-color:  #eed0c0;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col1 {
#             background-color:  #5e7de7;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col4 {
#             background-color:  #84a7fc;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col5 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col6 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col7 {
#             background-color:  #86a9fc;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col8 {
#             background-color:  #7a9df8;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col9 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col10 {
#             background-color:  #85a8fc;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col11 {
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col12 {
#             background-color:  #dbdcde;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col13 {
#             background-color:  #81a4fb;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col14 {
#             background-color:  #b9d0f9;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col15 {
#             background-color:  #d9dce1;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row2_col16 {
#             background-color:  #e0dbd8;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col0 {
#             background-color:  #4961d2;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col1 {
#             background-color:  #a5c3fe;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col4 {
#             background-color:  #6a8bef;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col5 {
#             background-color:  #9abbff;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col6 {
#             background-color:  #80a3fa;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col7 {
#             background-color:  #8fb1fe;
#             color:  #000000;
#         }    #T_690b0840_8dcb_11ea_a4a1_c49dedb01420row3_col8 {
#             background-color:  #6f92f3;

# %% [markdown]
# # Machine Learning Model

# %%
# Define Features and Target
X = df1.iloc[:, 1:15] # Features from 2nd to 14th columns of data frame with all rows
y = df1.iloc[:, 15:16] # Target: 16th columns of data frame with all rows

# %%
X.head(5)
# Out:
#    LIMIT_BAL  MARRIAGE  AGE  PAY_Status  TOT_BILL  TOT_PAY  zero_PAY_AMT  \
# 0      20000         1   24          13      7704      689             5
# 1     120000         2   26          15     17077     5000             2
# 2      90000         2   34          12    103171    11018             0
# 3      50000         1   37          10    233334     8388             0
# 4      50000         1   57          10    111339    59049             0
#
#    ExceedCredit  exPAY_positive  TOT_SPEND  SEX_female  \
# 0             0               0       4602           1
# 1             0               2       5682           1
# 2             0               0      35257           1
# 3             0               0      54378           1
# 4             0               0      66987           0
#
#    EDUCATION_graduate school  EDUCATION_high school  EDUCATION_university
# 0                          0                      0                     1
# 1                          0                      0                     1
# 2                          0                      0                     1
# 3                          0                      0                     1
# 4                          0                      0                     1

# %%
y.head(5)
# Out:
#    default payment next month_default
# 0                                   1
# 1                                   1
# 2                                   0
# 3                                   0
# 4                                   0

# %%
# Split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state= 123)

# %%
# print the shapes of the new X objects
print(X_train.shape)
print(X_test.shape)
# Out:
# (18000, 14)
# (12000, 14)

# %%
# print the shapes of the new y objects
print(y_train.shape)
print(y_test.shape)
# Out:
# (18000, 1)
# (12000, 1)

# %% [markdown]
# # Logistic regression

# %%
# import the Logistic Regression class
from sklearn.linear_model import LogisticRegression

# instantiate the model (using the default parameters)
logreg = LogisticRegression()

# train the model on the training set
logreg.fit(X_train, y_train)
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
# make predictions on the testing set and store the predicted response values
y_pred = logreg.predict(X_test)

# compute classification accuracy for the logistic regression model
from sklearn import metrics
# compare actual response values (y_test) with predicted response values (y_pred)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.78075

# %% [markdown]
# # K nearest neighbors

# %%
#Import the KNeighborsClassifier class 
from sklearn.neighbors import KNeighborsClassifier

# instantiate the model (using the value K=3)
knn = KNeighborsClassifier(n_neighbors=3)

# fit the model with data
knn.fit(X_train, y_train)
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:8: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='uniform')

# %%
# store the predicted response values
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.7435833333333334

# %%
# Repeat for KNN with K=5:
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0.7574166666666666

# %%
# try K=1 through K=25 and record testing accuracy
k_range = list(range(1, 26))
scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train, y_train)
    y_pred = knn.predict(X_test)
    scores.append(metrics.accuracy_score(y_test, y_pred))
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\ipykernel_launcher.py:6: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().

# %%
# import Matplotlib (scientific plotting library)
import matplotlib.pyplot as plt

# allow plots to appear within the notebook
# %matplotlib inline

# plot the relationship between K and testing accuracy
plt.plot(k_range, scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Testing Accuracy')
# Out:
# Text(0, 0.5, 'Testing Accuracy')

# %% [markdown]
# # K-fold cross-validation

# %%
from sklearn.model_selection import cross_val_score
# 10-fold cross-validation with K=5 for KNN (the n_neighbors parameter)
knn = KNeighborsClassifier(n_neighbors=5)
scores = cross_val_score(knn, X, y, cv=10, scoring='accuracy')
print(scores)
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [0.74833333 0.75       0.74766667 0.75066667 0.753      0.73833333
#  0.75933333 0.76166667 0.76366667 0.75933333]

# %%
# use average accuracy as an estimate of out-of-sample accuracy
print(scores.mean())
# Out:
# 0.7532

# %%
# search for an optimal value of K for KNN
k_range = list(range(1, 25))
k_scores = []
for k in k_range:
    knn = KNeighborsClassifier(n_neighbors=k)
    scores = cross_val_score(knn, X, y, cv=10, scoring='accuracy')
    k_scores.append(scores.mean())
print(k_scores)
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# ...
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# [0.6914333333333333, 0.7634666666666667, 0.7370666666666665, 0.77, 0.7532, 0.7715, 0.7619333333333332, 0.7741999999999999, 0.7680666666666667, 0.776, 0.7711666666666667, 0.7768999999999999, 0.7738, 0.7783666666666667, 0.7756000000000001, 0.7787666666666667, 0.7760666666666667, 0.7780666666666667, 0.7758, 0.7786666666666666, 0.7771333333333335, 0.7786000000000001, 0.7782666666666668, 0.7792]

# %%
# plot the value of K for KNN (x-axis) versus the cross-validated accuracy (y-axis)
plt.plot(k_range, k_scores)
plt.xlabel('Value of K for KNN')
plt.ylabel('Cross-Validated Accuracy')
# Out:
# Text(0, 0.5, 'Cross-Validated Accuracy')

# %%
# 10-fold cross-validation with the best KNN model
knn = KNeighborsClassifier(n_neighbors=20)
print(cross_val_score(knn, X, y, cv=10, scoring='accuracy').mean())
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\model_selection\_validation.py:515: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# 0.7738666666666667

# %%
# 10-fold cross-validation with logistic regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
print(cross_val_score(logreg, X, y, cv=10, scoring='accuracy').mean())
# Out:
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.7787999999999999
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\cthian972\anaconda3\envs\hw\lib\site-packages\sklearn\utils\validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn.datasets import make_classification

# Build a classification task using 3 informative features
X, y = make_classification(n_samples=1000, n_features=25, n_informative=3,
                           n_redundant=2, n_repeated=0, n_classes=8,
                           n_clusters_per_class=1, random_state=0)

# %%
# Create the RFE object and compute a cross-validated score.
from sklearn.svm import SVC
svc = SVC(kernel="linear")

# %%
# The "accuracy" scoring is proportional to the number of correct classifications
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_selection import RFECV
rfecv = RFECV(estimator=svc, step=1, cv=StratifiedKFold(2), scoring='accuracy')

# %%
rfecv.fit(X, y)
# Out:
# RFECV(cv=StratifiedKFold(n_splits=2, random_state=None, shuffle=False),
#       estimator=SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None,
#                     coef0=0.0, decision_function_shape='ovr', degree=3,
#                     gamma='scale', kernel='linear', max_iter=-1,
#                     probability=False, random_state=None, shrinking=True,
#                     tol=0.001, verbose=False),
#       min_features_to_select=1, n_jobs=None, scoring='accuracy', step=1,
#       verbose=0)

# %%
print("Optimal number of features : %d" % rfecv.n_features_)
# Out:
# Optimal number of features : 3

# %%
# Plot number of features VS. cross-validation scores
plt.figure()
plt.xlabel("Number of features selected")
plt.ylabel("Cross validation score (nb of correct classifications)")
plt.plot(range(1, len(rfecv.grid_scores_) + 1), rfecv.grid_scores_)
plt.show()

# %% [markdown]
# # Feature Selection to remove irrelevant features for better performance model, easier to understand and run faster
